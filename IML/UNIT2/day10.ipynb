# %% [markdown]
# # Import necessaey libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("datasets/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df.cov(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Find the Covariance and Correlation of the Given Data

# %%
df=pd.read_csv("datasets/nums.csv")
df
# Out:
#     x   y
# 0  10   9
# 1   6   4
# 2   9   6
# 3  10   9
# 4  12  11
# 5  13  13
# 6  11   8
# 7   9   4

# %% [markdown]
# ### correlation

# %%
df.corr()
# Out:
#           x         y
# x  1.000000  0.895833
# y  0.895833  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### covariance

# %%
df.cov()
# Out:
#           x          y
# x  4.571429   6.142857
# y  6.142857  10.285714

# %%
sns.heatmap(df.cov(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Outliers

# %%
y=[2,7,10,12,16,20]
fig=plt.figure(figsize=(2,2))
bp=plt.boxplot(y)
plt.show()
